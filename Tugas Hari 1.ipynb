# %% [markdown]
# <h2>Soal 1: Hello World to Python</h2>
#
# Print Say Hello World to Python

# %%
Sapa = "Hello World Python"
print(Sapa)
# Out:
# Hello World Python

# %% [markdown]
# Expected Output :
#
# Hello World Python

# %% [markdown]
# <h2>Soal 2: Aritmatika di Python </h2>
#
# - Buat statement pertambahan antara 2 number di Python
# - Buat statement perkurangan antara 2 number di Python
# - Buat statement perkalian antara 2 number di Python
# - Buat statement pembagian antara 2 number di Python

# %%
#membuat variabel dengan nilai tertentu
a= 10
b= 5
c= 7

# %%
#tambah
d = a+b
print ("Hasil penjumlahan",a," + ",b," adalah =",d)
# Out:
# Hasil penjumlahan 10  +  5  adalah = 15

# %%
#pengurangan
e = a-c
print ("Hasil pengurangan dari",a," - ",c," adalah =",e)
# Out:
# Hasil pengurangan dari 10  -  7  adalah = 3

# %%
#perkalian
f = a*c
print ("Hasil perkalian dari",a," * ",c," adalah =",f)
# Out:
# Hasil perkalian dari 10  *  7  adalah = 70

# %%
#pembagian
g = a/b
print ("Hasil pembagian dari",a," : ",b," adalah =",g)
# Out:
# Hasil pembagian dari 10  :  5  adalah = 2.0

# %% [markdown]
# <h2>Quiz 3: Assign Variable dan Tipe Data Integer, Float </h2>
#
# - Buat suatu variabel a dan b, dimana a dan b adalah nilai bertipe data numeric
# - Berikan suatu nilai bertipe data integer, hasil pembagian dari a dengan b
# - Berikan suatu nilai bertipe data float, hasil pembagian dari a dengan b

# %%
a1=int(14)
b1=int(2)

# %%
#hasil pembagian
c1 = a1/b1
print(int(c1))
# Out:
# 7

# %%
#hasil berupa float
print(float(c1))
# Out:
# 7.0

# %% [markdown]
# <h2>Soal 4: String Operation </h2>
#
# - masukan nama depan kamu kedalam suatu variable firstname
# - masukan nama belakang kamu kedalam suatu variable lastname
# - tampilkan suatu kalimat 'Hello sanbercode, saya firstname lastname! saya siap belajar python data science dasar.'

# %%
firstname= 'Nurpita'
lastname = 'Sari'

# %%
print('Hello sanbercode, saya {} {}! saya siap belajar python data science dasar.'.format(firstname, lastname))
# Out:
# Hello sanbercode, saya Nurpita Sari! saya siap belajar python data science dasar.

# %% [markdown]
# Expected Output :
#
# Hello sanbercode, saya Afrida Hafizhatul Ulum! saya siap belajar python data science dasar.

# %% [markdown]
# <h2>Soal 5: Tipe Data</h2>
#
# Lengkapi code di bawah ini untuk menghasilkan output yang sesuai

# %%
usia = 21
kata = 'usiaku: '
print(kata + str(usia) + ' tahun')
# Out:
# usiaku: 21 tahun

# %% [markdown]
# Expected Output : (sesuai usia masing-masing)
#
# usiaku: 28 tahun
